# %% [markdown]
# <a href="https://colab.research.google.com/github/kerseyi/20h8/blob/master/dinoTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ml5js/training-dcgan
# Out:
# Cloning into 'training-dcgan'...
# remote: Enumerating objects: 45, done.
# remote: Counting objects: 100% (45/45), done.
# remote: Compressing objects: 100% (31/31), done.
# remote: Total 100 (delta 20), reused 35 (delta 13), pack-reused 55
# Receiving objects: 100% (100/100), 160.89 KiB | 885.00 KiB/s, done.
# Resolving deltas: 100% (36/36), done.

# %%
# !tar -C training-dcgan/images/ -xf dataset.tar.gz --strip-components=1

# %%
# %cd training-dcgan
# Out:
# /content/training-dcgan

# %%
# !./datatool.py --size 128
# Out:
# I0428 15:05:52.678725 139845450381184 datatool.py:125] Creating custom dataset ./dataset from ./images
#
# ./images/dinoMaster (1).jpeg
# ./images/dinoMaster (10).jpeg
# ./images/dinoMaster (100).jpeg
# ./images/dinoMaster (145).jpeg
# ./images/dinoMaster (104).jpeg
# ./images/dinoMaster (105).jpeg
# ./images/dinoMaster (107).jpeg
# ./images/dinoMaster (110).jpeg
# ./images/dinoMaster (112).jpeg
# ./images/dinoMaster (114).jpeg
# ./images/dinoMaster (115).jpeg
# ./images/dinoMaster (118).jpeg
# ./images/dinoMaster (12).jpeg
# ./images/dinoMaster (120).jpeg
# ./images/dinoMaster (126).jpeg
# ./images/dinoMaster (13).jpeg
# ./images/dinoMaster (131).jpeg
# ./images/dinoMaster (132).jpeg
# ./images/dinoMaster (136).jpeg
# ./images/dinoMaster (140).jpeg
# ./images/dinoMaster (142).jpeg
# ./images/dinoMaster (143).jpeg
# ./images/dinoMaster (144).jpeg
# ./images/dinoMaster (103).jpeg
# ./images/dinoMaster (108).jpeg
# ./images/dinoMaster (11).jpeg
# ./images/dinoMaster (146).jpeg
# ...

# %%
# !./chainer_dcgan.py --arch resnet128 --image_size 128
# Out:
# use gpu 0
# anneled lr for g: 0.0001
# anneled lr for d: 0.0001
#      total [..................................................]  0.01%
# this epoch [..................................................]  1.43%
#         10 iter, 1 epoch / 100000 iterations
#        inf iters/sec. Estimated time to finish: 0:00:00.
# epoch       iteration   elapsed_time  gen/loss_adv  dis/loss_adv  dis/loss_gp
#      total [..................................................]  0.02%
# this epoch [#.................................................]  2.85%
#         20 iter, 2 epoch / 100000 iterations
#       0.49 iters/sec. Estimated time to finish: 2 days, 8:40:40.418685.
#      total [..................................................]  0.03%
# this epoch [##................................................]  4.28%
#         30 iter, 3 epoch / 100000 iterations
#    0.49006 iters/sec. Estimated time to finish: 2 days, 8:39:56.022122.
# ...
